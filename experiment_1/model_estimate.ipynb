# %%
# %reload_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
from firth import firthLogit
from utilityModel import utilLogit

# %%
df_risky_choice = pd.read_csv('risky_choice_obs.csv',sep=',',index_col=0)

# %%
mod = utilLogit(df_risky_choice).fit()
mod
# Out:
# C:\Users\zarkwang\AppData\Roaming\Python\Python310\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\zarkwang\AppData\Roaming\Python\Python310\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 1711.870823367068
#        x: [ 6.946e-01  1.904e+00  2.245e-13]
#      nit: 26
#      jac: [-6.654e-02  1.068e-04  1.375e+01]
#     nfev: 121
#     njev: 26

# %%
risk_amount_list = df_risky_choice['risk_amount'].unique()
for r in risk_amount_list:
    subset = df_risky_choice[(df_risky_choice['risk_amount']==r)&(df_risky_choice['choice']==1)].groupby('pid')['safe_amount'].min()
    plt.hist(subset,bins=10)

# %%
df_risky_choice
# Out:
#                    prolific_id  duration  pid question  choice  row_id  q_id  \
# 1     5d5bbd713348d20019c7e832       287    1    Q10_1       0       1    10
# 2     62b1ff970dfb7055f35d6937       289    2    Q10_1       0       1    10
# 3     5e1ed72fb0285720462a8649       297    3    Q10_1       1       1    10
# 4     5f2b3239b986da551f26bec7       319    4    Q10_1       0       1    10
# 5     5eaacf92bb492a0378be2dbf       342    5    Q10_1       0       1    10
# ...                        ...       ...  ...      ...     ...     ...   ...
# 3293  5eafe830cf726802582beaa7      1569  153    Q12_7       1       7    12
# 3294  60eb4444f2ff728c1df7ffc3      1824  154    Q12_7       1       7    12
# 3295  609408e1ef7e7d611c5a06ac      1827  155    Q12_7       1       7    12
# 3296  604604bf082da501e40808c3      2163  156    Q12_7       1       7    12
# 3297  63cedbbe158c7caa960e79a7      2205  157    Q12_7       0       7    12
#
#       risk_amount  safe_amount
# ...
